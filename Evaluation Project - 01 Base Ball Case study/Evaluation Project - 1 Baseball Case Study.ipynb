# %% [markdown]
# __Baseball Case Study__
#
# Problem Statement:
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# Major League Baseball (MLB) is a professional baseball organization with a total of 30 teams in the United States and Canada. Established in 1903
#
# This data set is useful for examining the relationships between wins, runs scored in a season, and a number of other Team statistics.
#
# __Input features:__ Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# __Input features explained__
#
# Runs : A player is awarded a run if he crosses the plate to score his team a run. When tallying runs scored, the way in which a player reached base is not considered. If a player reaches base by an error or a fielder's choice, as long as he comes around to score, he is still credited with a run. If a player enters the game as a pinch-runner and scores, he is also credited with a run.
#
# At_Bats : An official at-bat comes when a batter reaches base via a fielder's choice, hit or an error (not including catcher's interference) or when a batter is put out on a non-sacrifice. (Whereas a plate appearance refers to each completed turn batting, regardless of the result.) Number of At Bats
#
# Hits : A hit occurs when a batter strikes the baseball into fair territory and reaches base without doing so via an error or a fielder's choice. There are four types of hits in baseball: singles, doubles, triples and home runs. All four are counted equally when deciphering batting average. If a player is thrown out attempting to take an extra base (e.g., turning a single into a double), that still counts as a hit.
#
# Doubles : A batter is credited with a double when he hits the ball into play and reaches second base without the help of an intervening error or attempt to put out another baserunner.
#
# Triples : Often called "the most exciting play in baseball," a triple occurs when a batter hits the ball into play and reaches third base without the help of an intervening error or attempt to put out another baserunner.
#
# Home_Runs : A home run occurs when a batter hits a fair ball and scores on the play without being put out or without the benefit of an error. In almost every instance of a home run, a batter hits the ball in the air over the outfield fence in fair territory.
#
# Walks : A walk (or base on balls) occurs when a pitcher throws four pitches out of the strike zone, none of which are swung at by the hitter. After refraining from swinging at four pitches out of the zone, the batter is awarded first base. In the scorebook, a walk is denoted by the letters BB.
#
# Strikeouts : A strikeout occurs when a pitcher throws any combination of three swinging or looking strikes to a hitter. ... However, even if the batter reaches first base safely, the pitcher and the batter are still credited with a strikeout in the scorebook. In the scorebook, a strikeout is denoted by the letter K.
#
# Stolen_Bases : A stolen base occurs when a baserunner advances by taking a base to which he isn't entitled. This generally occurs when a pitcher is throwing a pitch, but it can also occur while the pitcher still has the ball or is attempting a pickoff, or as the catcher is throwing the ball back to the pitcher
#
# Runs_Allowed : An inherited runner is any baserunner who is already on base when a relief pitcher enters the game. Any inherited runners who score against a relief pitcher are not charged to his ERA; however, there are a few statistics that take into account a pitcher's success at stranding runners on base.
#
# Earned_Runs : An earned run is any run that scores against a pitcher without the benefit of an error or a passed ball. Often, it is the judgment of the official scorer as to whether a specific run would've scored without the defensive mishap. If a pitcher exits a game with runners on base, any earned runs scored by those runners will count against him.
#
# ERA : Earned run average represents the number of earned runs a pitcher allows per nine innings -- with earned runs being any runs that scored without the aid of an error or a passed ball. ERA is the most commonly accepted statistical tool for evaluating pitchers.
#
# Colmplete_Games : A pitcher earns a complete game if he pitches the entire game for his team regardless of how long it lasts. If the game is shortened by rain or if it lasts into extra innings, it counts as a complete game if the pitcher was the only pitcher to record an appearance for his team.
#
# Shutouts : A starting pitcher is credited with a shutout when he pitches the entire game for a team and does not allow the opposition to score. By definition, any pitcher who throws a shutout is also awarded a win. Because he recorded every out for his team and didn't allow a run, his team could only have won.
#
# Saves : A save is awarded to the relief pitcher who finishes a game for the winning team, under certain circumstances. A pitcher cannot receive a save and a win in the same game.
#
# Errors : A fielder is given an error if, in the judgment of the official scorer, he fails to convert an out on a play that an average fielder should have made. Fielders can also be given errors if they make a poor play that allows one or more runners to advance on the bases. A batter does not necessarily need to reach base for a fielder to be given an error. If he drops a foul ball that extends an at-bat, that fielder can also be assessed an error.
#
#
# __Output:__ Number of predicted wins (W)
#
# __output features explained__
#
# Wins : Number of predicted Wins [W]
#
#
# __GOAL:__The goal is to predict the Number of predicted wins (W)

# %%
#Importing  required Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#importing data
df=pd.read_csv("baseball.csv")

# %%
#Viewing the dataset imported
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
#Viewing the first 5 rows in the data
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#Viewing the last 5 rows in the data
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
#Viewing the columns
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# __The contents of the above columns can be explained as follows-__
#
#
# __Input features:__
#
# R - Runs
#
# AB - At Bats
#
# H - Hits
#
# 2B - Doubles
#
# 3B - Triples
#
# HR - Homeruns
#
# BB - Walks
#
# SO - Strikeouts
#
# SB - Stolen Bases
#
# RA - Run Allowed
#
# ER - Earned Runs
#
# ERA - Earned Run Average
#
# CG - Complete games
#
# SHO - Shutouts
#
# SV - Saves
#
# E - Errors
#
#
# __Output features:__
#
# W - Number of predicted wins

# %%
#renaming the columns

df.rename(columns = {'W':'Wins', 'R':'Runs', 'AB':'At_Bats', 'H':'Hits', '2B':'Doubles', '3B':'Triples', 
                       'HR':'Home_Runs', 'BB':'Walks', 'SO':'Strikeouts', 'SB':'Stolen_Bases', 'RA':'Runs_Allowed', 
                       'ER':'Earned_Runs', 'CG':'Complete_Games', 'SHO':'Shutouts', 'SV':'Saves', 'E':'Errors'},inplace = True)

# %%
#display the data after renaming
df.head()
# Out:
#    Wins  Runs  At_Bats  Hits  Doubles  Triples  Home_Runs  Walks  Strikeouts  \
# 0    95   724     5575  1497      300       42        139    383         973
# 1    83   696     5467  1349      277       44        156    439        1264
# 2    81   669     5439  1395      303       29        141    533        1157
# 3    76   622     5533  1381      260       27        136    404        1231
# 4    74   689     5605  1515      289       49        151    455        1259
#
#    Stolen_Bases  Runs_Allowed  Earned_Runs   ERA  Complete_Games  Shutouts  \
# 0           104           641          601  3.73               2         8
# 1            70           700          653  4.07               2        12
# 2            86           640          584  3.67              11        10
# 3            68           701          643  3.98               7         9
# 4            83           803          746  4.64               7        12
#
#    Saves  Errors
# 0     56      88
# ...

# %% [markdown]
# After renaming, the data looks better and its easier for us to analyse the features with their names.

# %% [markdown]
# # Statistical Summary

# %%
#Checking the info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Wins            30 non-null     int64
#  1   Runs            30 non-null     int64
#  2   At_Bats         30 non-null     int64
#  3   Hits            30 non-null     int64
#  4   Doubles         30 non-null     int64
#  5   Triples         30 non-null     int64
#  6   Home_Runs       30 non-null     int64
#  7   Walks           30 non-null     int64
#  8   Strikeouts      30 non-null     int64
#  9   Stolen_Bases    30 non-null     int64
#  10  Runs_Allowed    30 non-null     int64
#  11  Earned_Runs     30 non-null     int64
#  12  ERA             30 non-null     float64
#  13  Complete_Games  30 non-null     int64
#  14  Shutouts        30 non-null     int64
#  15  Saves           30 non-null     int64
#  16  Errors          30 non-null     int64
# dtypes: float64(1), int64(16)
# ...

# %% [markdown]
# By looking at above info it is quite clear that the dataset has no null values. All the columns of the data are in integer data type except for ERA column, which is float type.

# %%
#Checking the shape of the dataset
df.shape
# Out:
# (30, 17)

# %% [markdown]
# The data has 30 rows and 17 columns.

# %%
#Viewing the description of data
df.describe()
# Out:
#              Wins        Runs      At_Bats         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples   Home_Runs       Walks  Strikeouts  Stolen_Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# ...

# %% [markdown]
# The above table gives the statistical information of the dataset. The summary of this dataset can be analysed as follows
#
# __Key Observations:__
#
# 1. The count of all the columns is same, which says there are no missing values in the dataset
#
# 2. The difference between 3rd quartile/75th Percentile and max is higher in the following columns
#     - Wins
#     - Runs
#     - At_Bats
#     - Home_Runs	Walks
#     - Strikeouts
#     - Stolen_Bases
#     - Runs_Allowed
#     - Earned_Runs
#     - Complete_Games
#     - Shutouts
#     - Saves
#     - Errors
# This shows there are outliers present in these columns.
#
# 3. The mean is close to the median in following columns
#     - Wins
#     - Runs
#     - At_Bats
#     - Doubles
#     - Triples
#     - ERA
#     - Saves
#
# These columns where the mean and median are close, the data is fairly balanced, or symmetric on each side
#
# 4. The mean is more than median (50th percentile) in following columns
#     - Hits
#     - Home_Runs
#     - Complete_Games
#     - Errors
#
# This means the distribution of data is skewed to the right when the mean is more than the median
#
# 5. The median (50th percentile) is more than mean in following columns
#     - Walks
#     - Strikeouts
#     - Runs_Allowed
#     - Earned_Runs
#     - Shutouts
#
# If the mean is much smaller than the median, the data are generally skewed left; a few smaller values bring the mean down.
#
# 6. The mean is equal to the median in following columns
#     - Stolen_Bases
#
# These columns where the mean and median are equal, the data is balanced and symmetric on each side

# %% [markdown]
# # EDA (EXPLORATORY DATA ANALYSIS)

# %%
#Checking the data types of all columns
df.dtypes
# Out:
# Wins                int64
# Runs                int64
# At_Bats             int64
# Hits                int64
# Doubles             int64
# Triples             int64
# Home_Runs           int64
# Walks               int64
# Strikeouts          int64
# Stolen_Bases        int64
# Runs_Allowed        int64
# Earned_Runs         int64
# ERA               float64
# Complete_Games      int64
# Shutouts            int64
# Saves               int64
# Errors              int64
# dtype: object

# %% [markdown]
# Here we have ERA with float type data. Else all columns have integer type data.

# %%
#Checking unique values of each column
df.nunique()
# Out:
# Wins              24
# Runs              28
# At_Bats           29
# Hits              29
# Doubles           22
# Triples           23
# Home_Runs         27
# Walks             29
# Strikeouts        29
# Stolen_Bases      27
# Runs_Allowed      30
# Earned_Runs       30
# ERA               30
# Complete_Games     9
# Shutouts          12
# Saves             20
# Errors            21
# dtype: int64

# %% [markdown]
# Above are the unique value counts in each column of the dataset.

# %%
#Checking null values in the dataset
df.isnull().sum()
# Out:
# Wins              0
# Runs              0
# At_Bats           0
# Hits              0
# Doubles           0
# Triples           0
# Home_Runs         0
# Walks             0
# Strikeouts        0
# Stolen_Bases      0
# Runs_Allowed      0
# Earned_Runs       0
# ERA               0
# Complete_Games    0
# Shutouts          0
# Saves             0
# Errors            0
# dtype: int64

# %% [markdown]
# As analysed we donot have any null values in the dataset.

# %%
#Checking for null values using a heatmap
plt.figure(figsize=[10,6])
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# After visualizing the dataset using heatmap, it is clear that there are no null values present.

# %%
#Checking for unique values in the target column
df['Wins'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %% [markdown]
# These are the unique values present in the target column of the dataset

# %%
#Checking for empty observations
df.loc[df['Wins'] == " "]
# Out:
# Empty DataFrame
# Columns: [Wins, Runs, At_Bats, Hits, Doubles, Triples, Home_Runs, Walks, Strikeouts, Stolen_Bases, Runs_Allowed, Earned_Runs, ERA, Complete_Games, Shutouts, Saves, Errors]
# Index: []

# %% [markdown]
# There are no empty observations in the data set.

# %%
#Checking value counts of target column
df['Wins'].value_counts()
# Out:
# 68     3
# 83     2
# 74     2
# 76     2
# 81     2
# 64     1
# 93     1
# 92     1
# 90     1
# 88     1
# 87     1
# 86     1
# 85     1
# 84     1
# 80     1
# 97     1
# 100    1
# 78     1
# 63     1
# 79     1
# 71     1
# 67     1
# 98     1
# 95     1
# Name: Wins, dtype: int64

# %% [markdown]
# Above are the value counts of target column.

# %% [markdown]
# # VISUALISATION:

# %% [markdown]
# ### UNIVARIATE ANALYSIS:

# %%
for i in df.columns:
    plt.figure()
    sns.distplot(df[i])

# %%
df.plot.bar(subplots=True,figsize=(20,20))
# Out:
# array([<AxesSubplot:title={'center':'Wins'}>,
#        <AxesSubplot:title={'center':'Runs'}>,
#        <AxesSubplot:title={'center':'At_Bats'}>,
#        <AxesSubplot:title={'center':'Hits'}>,
#        <AxesSubplot:title={'center':'Doubles'}>,
#        <AxesSubplot:title={'center':'Triples'}>,
#        <AxesSubplot:title={'center':'Home_Runs'}>,
#        <AxesSubplot:title={'center':'Walks'}>,
#        <AxesSubplot:title={'center':'Strikeouts'}>,
#        <AxesSubplot:title={'center':'Stolen_Bases'}>,
#        <AxesSubplot:title={'center':'Runs_Allowed'}>,
#        <AxesSubplot:title={'center':'Earned_Runs'}>,
#        <AxesSubplot:title={'center':'ERA'}>,
#        <AxesSubplot:title={'center':'Complete_Games'}>,
#        <AxesSubplot:title={'center':'Shutouts'}>,
#        <AxesSubplot:title={'center':'Saves'}>,
#        <AxesSubplot:title={'center':'Errors'}>], dtype=object)

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'Wins'}>,
#         <AxesSubplot:title={'center':'Runs'}>,
#         <AxesSubplot:title={'center':'At_Bats'}>,
#         <AxesSubplot:title={'center':'Hits'}>],
#        [<AxesSubplot:title={'center':'Doubles'}>,
#         <AxesSubplot:title={'center':'Triples'}>,
#         <AxesSubplot:title={'center':'Home_Runs'}>,
#         <AxesSubplot:title={'center':'Walks'}>],
#        [<AxesSubplot:title={'center':'Strikeouts'}>,
#         <AxesSubplot:title={'center':'Stolen_Bases'}>,
#         <AxesSubplot:title={'center':'Runs_Allowed'}>,
#         <AxesSubplot:title={'center':'Earned_Runs'}>],
#        [<AxesSubplot:title={'center':'ERA'}>,
#         <AxesSubplot:title={'center':'Complete_Games'}>,
#         <AxesSubplot:title={'center':'Shutouts'}>,
#         <AxesSubplot:title={'center':'Saves'}>],
#        [<AxesSubplot:title={'center':'Errors'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# __Observations__:
# Almost all the columns are near normally distributed, Except Runs, Strikeouts, Complete_Games and Errors. There is skewness present in some of the variables.

# %%
df.plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# At Bat has highest numbers.

# %%
#Target column - Wins

plt.figure(figsize = (14,8))
plt.style.use('seaborn')
sns.countplot(df['Wins'])
plt.title('Winning Estimations')
plt.show()

# %% [markdown]
# Observations:
# - There are 3 teams with the wins count: "68"
# - There are 2 teams with the wins count: "74","76","81","83" respectively

# %%
#plotting the columns
fig, ax = plt.subplots(6, 2, figsize = (15, 13))
sns.boxplot(x= df["Wins"], ax = ax[0,0])
sns.distplot(df['Wins'], ax = ax[0,1])
sns.boxplot(x= df["Runs"], ax = ax[1,0])
sns.distplot(df['Runs'], ax = ax[1,1])
sns.boxplot(x= df["At_Bats"], ax = ax[2,0])
sns.distplot(df['At_Bats'], ax = ax[2,1])
sns.boxplot(x= df["Hits"], ax = ax[3,0])
sns.distplot(df['Hits'], ax = ax[3,1])
sns.boxplot(x= df["Doubles"], ax = ax[4,0])
sns.distplot(df['Doubles'], ax = ax[4,1])
sns.boxplot(x= df["Triples"], ax = ax[5,0])
sns.distplot(df['Triples'], ax = ax[5,1])
sns.boxplot(x= df["Home_Runs"], ax = ax[1,0])
sns.distplot(df['Home_Runs'], ax = ax[1,1])
sns.boxplot(x= df["Walks"], ax = ax[2,0])
sns.distplot(df['Walks'], ax = ax[2,1])
sns.boxplot(x= df["Strikeouts"], ax = ax[3,0])
sns.distplot(df['Strikeouts'], ax = ax[3,1])
sns.boxplot(x= df["Stolen_Bases"], ax = ax[4,0])
sns.distplot(df['Stolen_Bases'], ax = ax[4,1])
sns.boxplot(x= df["Runs_Allowed"], ax = ax[5,0])
sns.distplot(df['Runs_Allowed'], ax = ax[5,1])
sns.boxplot(x= df["Earned_Runs"], ax = ax[4,0])
sns.distplot(df['Earned_Runs'], ax = ax[4,1])
sns.boxplot(x= df["ERA"], ax = ax[5,0])
sns.distplot(df['ERA'], ax = ax[5,1])
sns.distplot(df['Complete_Games'], ax = ax[4,1])
sns.boxplot(x= df["Complete_Games"], ax = ax[5,0])
sns.distplot(df['Shutouts'], ax = ax[5,1])
sns.boxplot(x= df["Shutouts"], ax = ax[4,0])
sns.distplot(df['Saves'], ax = ax[4,1])
sns.boxplot(x= df["Saves"], ax = ax[5,0])
sns.distplot(df['Errors'], ax = ax[5,1])
sns.boxplot(x= df["Errors"], ax = ax[5,0])
plt.tight_layout()

# %% [markdown]
# __Observation:__
#
#
# - We could see some outliers in the following features
#    -  Runs
#    -  ERA
#    -  Shutouts
#    -  Saves
#    -  Errors
#
#
# - We shall remove the outliers in the further steps
#
# - Wins has normal distribution.
#
# - We see the columns Wins and Strikeouts have high dispersion.
#
# - Some columns have positive skewness and others negative.

# %% [markdown]
# # Bivariate analysis:

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,5])
plt.title('Comparision between Runs and At bats')
sns.scatterplot(df['Runs'],df['At_Bats'],hue=df["Wins"]);

# %% [markdown]
# As we can see, the no. of wins increasing with the no. of runs,i.e, they are directly proportional. But At bats doesn't have a significant effect on wins.

# %%
# Checking the relation between two variables
sns.relplot(x='Hits',y='Doubles',data=df,hue=df["Wins"]);

# %% [markdown]
# As the number of doubles increases number of wins is also incresing,i.e, they are directly proportional. But Hits doesn't show any proper pattern.

# %%
# Checking the relation between two variables
sns.scatterplot(df['Home_Runs'],df['Triples'],data=df,hue=df["Wins"]);

# %% [markdown]
# Home_Runs with Triples also doesn't show any proper pattern.

# %%
# Checking the relation between two variables
sns.scatterplot(df['Walks'],df['Strikeouts'],data=df,hue=df["Wins"]);

# %% [markdown]
# Walks and StrikeOuts also doesn't show any proper patternwith the wins

# %%
# Checking the relation between two variables
sns.scatterplot(df['Stolen_Bases'],df['Runs_Allowed'],data=df,hue=df["Wins"]);

# %% [markdown]
# Runs_Allowed and Stolen_Bases also doesn't show any proper pattern with the wins

# %%
# Checking the relation between two variables
sns.scatterplot(df['Earned_Runs'],df['ERA'],data=df,hue=df["Wins"]);

# %% [markdown]
# As Earned_Runs and ERA increase, the winning number decreases, and vice a versa . This shows they are indirectly proportional to wins

# %%
# Checking the relation between two variables
sns.scatterplot(df['Complete_Games'],df['Shutouts'],data=df,hue=df["Wins"]);

# %% [markdown]
# Complete_Games and Shutouts doesn't show any proper pattern.

# %%
# Checking the relation between two variables
sns.scatterplot(df['Saves'],df['Errors'],data=df,hue=df["Wins"]);

# %% [markdown]
# Lesser the Saves lesser the wins. Errors doesn't show any proper pattern.

# %%
# Checking the relation between two variables
sns.regplot(df['Saves'],df['Wins']);
plt.xlabel("Saves")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# Both the features have linear relationship

# %%
# Checking the relation between two variables
sns.regplot(df['Triples'],df['Wins'],color="b");
plt.xlabel("Triples")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# we can observe a negative linear relation which means above pair of features are inversely proportional to each other.

# %%
# Checking the relation between two variables
sns.lineplot(df['Doubles'],df['Wins'],color="b");
plt.xlabel("Doubles")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# If the number of doubles is high then the wining rate is also high.

# %%
# Checking the relation between two variables
sns.lineplot(df['Stolen_Bases'],df['Wins'],color="b");
plt.xlabel("Stolen Bases")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# The relationship between these variables is neither directly proportional nor indirectly proportional

# %%
plt.figure(figsize=(30,6))
plt.title('Earned Runs vs Earned Runs Average')
sns.barplot(x='Earned_Runs',y='ERA',data=df)
# Out:
# <AxesSubplot:title={'center':'Earned Runs vs Earned Runs Average'}, xlabel='Earned_Runs', ylabel='ERA'>

# %% [markdown]
# __Observation:__
# - If the number of Runs earned increases then, the Earned Runs Average also increases
# - By this we can also say that our "Earned Runs" and "Earned Runs Average" data are consistent and directly proportional

# %%
# At Bats vs Wins

plt.figure(figsize=(30,10))
plt.title('At Bats vs Wins')
sns.barplot(x='At_Bats',y='Wins',data=df)
# Out:
# <AxesSubplot:title={'center':'At Bats vs Wins'}, xlabel='At_Bats', ylabel='Wins'>

# %% [markdown]
# We could see that "At_Bats" column data has no incresing or decreasing impact with respect to increase or decrease of the "Wins". It is neutral.

# %%
# 'Hits vs Runs'

plt.figure(figsize=(15,5))
plt.title('Hits vs Runs')
sns.lineplot(x='Hits',y='Runs',data=df)
plt.show()

# %%
#Checking the maximum value in the Runs Column
df['Runs'].max()
# Out:
# 891

# %%
#To extract the row that has th maximum value in the Runs Column
df[df['Runs'] ==891]
# Out:
#    Wins  Runs  At_Bats  Hits  Doubles  Triples  Home_Runs  Walks  Strikeouts  \
# 5    93   891     5509  1480      308       17        232    570        1151
#
#    Stolen_Bases  Runs_Allowed  Earned_Runs  ERA  Complete_Games  Shutouts  \
# 5            88           670          609  3.8               7        10
#
#    Saves  Errors
# 5     34      88

# %% [markdown]
# Observation:
# - We can see that highest runs scored were "891",when the Number of Hits was "1480"
# - In the range of (1420 - 1480) as no. of hits were increasing the number of runs were also increasing.

# %%
#chekcing regression line on few columns
sns.pairplot(df, x_vars=['Runs','At_Bats','Hits','Doubles','Triples','Home_Runs','Walks','Strikeouts','Stolen_Bases','Runs_Allowed','Earned_Runs','ERA','Complete_Games','Shutouts','Saves','Errors'], y_vars=["Wins"],
             height=5, aspect=1, kind="reg");

# %% [markdown]
# __Observation:__ Between 'Wins’ and other attributes indicates the relationship is linear.

# %% [markdown]
# ## Multivariate Analysis

# %%
#checking multivariate analysis: in this case, one variable vs other variable:
sns.set(rc={'figure.figsize':(11.7,8.27)})
cData_attr = df.iloc[:, 0:7]
sns.pairplot(cData_attr, diag_kind='kde')

# %%
sns.pairplot(df,hue='Wins')

# %% [markdown]
# Above pair plots shows wheather two features are having good correaltion or if they are just scattered with out any pattern.

# %% [markdown]
# # Data Cleaning:

# %%
#Checking for outliers

plt.figure(figsize = (15,23))
plotnumber = 1

for column in df.iloc[:,1:]: #let's visualize only the features columns 
    if plotnumber<=16:
        ax = plt.subplot(8,2,plotnumber)
        sns.boxplot(df[column], palette="Paired")
        plt.xlabel(column,fontsize = 20)
    plotnumber += 1
plt.tight_layout()

# %%
df.plot(kind='box',fontsize=14,figsize=(25,25),color='b')
# Out:
# <AxesSubplot:>

# %% [markdown]
# __Observation:__
#
# We could see some outliers in the following features
#    -  Runs
#    -  ERA
#    -  Shutouts
#    -  Saves
#    -  Errors

# %% [markdown]
# # Removing Outliers:

# %% [markdown]
# ## I) Zscore method:

# %%
#Making alist of Features that has outliers
features=df[['Runs','ERA','Shutouts','Saves','Errors']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#     Wins  Runs  At_Bats  Hits  Doubles  Triples  Home_Runs  Walks  Strikeouts  \
# 0     95   724     5575  1497      300       42        139    383         973
# 1     83   696     5467  1349      277       44        156    439        1264
# 2     81   669     5439  1395      303       29        141    533        1157
# 3     76   622     5533  1381      260       27        136    404        1231
# 4     74   689     5605  1515      289       49        151    455        1259
# 6     87   764     5567  1397      272       19        212    554        1227
# 7     81   713     5485  1370      246       20        217    418        1331
# 8     80   644     5485  1383      278       32        167    436        1310
# 9     78   748     5640  1495      294       33        161    478        1148
# 10    88   751     5511  1419      279       32        172    503        1233
# 11    86   729     5459  1363      278       26        230    486        1392
# ...

# %% [markdown]
# The outliers have been removed using Zscore method

# %%
#Checking shape of new dataset
df_new.shape
# Out:
# (29, 17)

# %% [markdown]
# The new data set after removing outliers has 29 rows and 17 columns.

# %%
#Checking shape of old dataset
df.shape
# Out:
# (30, 17)

# %% [markdown]
# The data set previously had 30 rows and 17 columns.

# %%
#Checking dataloss
Dataloss = (((30-29)/30)*100)
Dataloss
# Out:
# 3.3333333333333335

# %% [markdown]
# The data loss in zscore method after removing outliers is 3.33% which is less than 10%. Let us try using IQR method.

# %% [markdown]
# ## II) IQR (Inter Quantile Range) method:

# %%
# 1st quantile
Q1=features.quantile(0.25)

# 3rd quantile
Q3=features.quantile(0.75)

# IQR
IQR=Q3 - Q1

df_1=df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# Using IQR method the outliers have been removed.

# %%
#Checking shape of new dataset
df_1.shape
# Out:
# (20, 17)

# %% [markdown]
# After removing the outliers using IQR method we have 20 rows and 17 columns in the data set.

# %%
#Checking shape of old dataset
df.shape
# Out:
# (30, 17)

# %% [markdown]
# The data set previously had 30 rows and 17 columns.

# %%
#Checking data loss in IQR method
Dataloss = (((30-20)/30)*100)
Dataloss
# Out:
# 33.33333333333333

# %% [markdown]
# We can notice a huge loss of data in IQR method.So let us stick to zscore for removing outliers.

# %% [markdown]
# # Checking for skewness:

# %%
#Checking for skewness
df_new.skew()
# Out:
# Wins              0.119013
# Runs             -0.215364
# At_Bats           0.169573
# Hits              0.783772
# Doubles          -0.335304
# Triples           0.090124
# Home_Runs         0.450862
# Walks             0.151193
# Strikeouts       -0.233815
# Stolen_Bases      0.494966
# Runs_Allowed      0.018155
# Earned_Runs       0.018461
# ERA               0.016693
# Complete_Games    0.854980
# Shutouts          0.526943
# Saves             0.627480
# Errors            0.840271
# dtype: float64

# %% [markdown]
# We can notice that there is skewness in
# - Hits
# - Complete games
# - Shutouts
# - Saves
# - Errors

# %% [markdown]
# # Removing skewness :

# %%
#list of all the features having skewness
skew_fea=["Hits","Complete_Games","Shutouts","Saves","Errors"]

# %%
#Removing skewness in H using log1p
df_new["Hits"]=np.log1p(df_new["Hits"])

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box_cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box_cox' or 'yeo-johnson'\n"

# %% [markdown]
# Using yeo-johnson method i have removed the skewness in Errors.

# %%
#Removing skewness using yeo-johnson
df_new[["Complete_Games","Shutouts","Saves","Errors"]] = scaler.fit_transform(df_new[["Complete_Games","Shutouts","Saves","Errors"]].values)

# %% [markdown]
# These are edited features after removing skewness.

# %%
#Checking skewness after removing skewness
df_new.skew()
# Out:
# Wins              0.119013
# Runs             -0.215364
# At_Bats           0.169573
# Hits              0.738455
# Doubles          -0.335304
# Triples           0.090124
# Home_Runs         0.450862
# Walks             0.151193
# Strikeouts       -0.233815
# Stolen_Bases      0.494966
# Runs_Allowed      0.018155
# Earned_Runs       0.018461
# ERA               0.016693
# Complete_Games   -0.045947
# Shutouts          0.000529
# Saves            -0.000925
# Errors            0.065585
# dtype: float64

# %% [markdown]
# The skewness is removed from the data set except Hits.
#
# We have tried removing skewness from Hits column using log, log1p, sqrt, cbrt and box-cox.Even after using all these methods i was able to remove 0.02 skewness from Hits column.
# And after trying to remove skewness in Hits using yeo-johnson method we get 0.0 skewness, after this we have checked correlation for all feature and found that the correlation of Hits with all the features was NaN.
# So its better to keep the skewness as it is since Hits has some relation with wins. Hence dropping Hits may affect the model training.

# %%
# After removing let's check how the data has been distributed in each column of skew_fea.

plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df_new[skew_fea]:
    if plotnumber<=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df_new[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# __Observations__: Skewness is removed to some extent.And the data is near normally distributed now.

# %% [markdown]
# # Checking the correlation

# %%
#Assigning a variable for correlation
cor=df_new.corr()

# %%
#Checking correlation
cor
# Out:
#                     Wins      Runs   At_Bats      Hits   Doubles   Triples  \
# Wins            1.000000  0.390451 -0.085780 -0.020785  0.384886 -0.206737
# Runs            0.390451  1.000000  0.438022  0.432236  0.469293  0.134204
# At_Bats        -0.085780  0.438022  1.000000  0.770154  0.490752  0.445604
# Hits           -0.020785  0.432236  0.770154  1.000000  0.527354  0.579735
# Doubles         0.384886  0.469293  0.490752  0.527354  1.000000  0.342419
# Triples        -0.206737  0.134204  0.445604  0.579735  0.342419  1.000000
# Home_Runs       0.245697  0.586894 -0.064653 -0.219201 -0.098695 -0.369299
# Walks           0.447513  0.258450 -0.137850 -0.221773  0.211243 -0.404852
# Strikeouts      0.156469  0.081158 -0.111243 -0.373301 -0.096772 -0.196586
# Stolen_Bases   -0.169503  0.075323  0.373674  0.420199  0.194308  0.483818
# Runs_Allowed   -0.823176 -0.013858  0.315499  0.243639 -0.215196  0.312750
# ...

# %%
#Plotting a heatmap to better understand the correlation between the features visually
plt.figure(figsize=(30,20))
sns.heatmap(df_new.corr(),linewidths=.1,annot=True)
plt.yticks(rotation=0);

# %% [markdown]
# __Observations__: We can notice that
#
# 1. The target column Wins(No.of wins) is positively correlated with
#
# - Runs
# - Doubles
# - Home_runs
# - Walks
# - Strikeouts
# - Complete_Games
# - Shoutouts
#
# 2. The target column Wins is higly positively correlated with
#
# - Saves
#
# 3. The target column Wins(No.of wins) is negatively correlated with
#
# - At_Bats
# - Hits
# - Errors
# - Triples
# - stolenBases
#
# 4. The target column Wins is higly negatively correlated with
#
# - Run_Allowed
# - Earned_Runs
# - ERA(Earned Runs Average)
#
#
# 5. Earned_Runs and ERA has high positive correlation with Runs_Allowed
#
# 6. Looking into the dependent features we can say that
#
# - Since Runs_Allowed, Earned_Runs and ERA acts as duplicates and all 3 columns has same kind of relation with target variable. We can drop any two of them and keep other one for model training.

# %%
plt.figure(figsize=(20,10))
df_new.corr()['Wins'].sort_values(ascending=False).drop(['Wins']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# We can observe that Complete_Games and Hits are least correlated with target column.So we can check the VIF and drop them.

# %%
#Droping least correlated column
df_new = df_new.drop(["Complete_Games"],axis=1)

# %%
#Checking the data set after droping least correlated column Complete_Games.
df_new.head()
# Out:
#    Wins  Runs  At_Bats      Hits  Doubles  Triples  Home_Runs  Walks  \
# 0    95   724     5575  7.311886      300       42        139    383
# 1    83   696     5467  7.207860      277       44        156    439
# 2    81   669     5439  7.241366      303       29        141    533
# 3    76   622     5533  7.231287      260       27        136    404
# 4    74   689     5605  7.323831      289       49        151    455
#
#    Strikeouts  Stolen_Bases  Runs_Allowed  Earned_Runs   ERA  Shutouts  \
# 0         973           104           641          601  3.73 -0.787002
# 1        1264            70           700          653  4.07  0.236737
# 2        1157            86           640          584  3.67 -0.252844
# 3        1231            68           701          643  3.98 -0.513555
# 4        1259            83           803          746  4.64  0.236737
#
#       Saves    Errors
# 0  1.532753 -0.348265
# 1  0.312020 -0.540820
# 2 -0.664137 -1.326125
# 3 -0.820689  0.650818
# ...

# %% [markdown]
# # Preprocessing:

# %%
#Assigned y as target variable and x as remaining features.
x = df_new.drop("Wins",axis=1)
y = df_new["Wins"]

# %% [markdown]
# # Scaling data using StandardScaler:

# %%
#importing necessary libraries
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
# Scaling data using standard scaler.
sc=StandardScaler()
X = pd.DataFrame(sc.fit_transform(x), columns=x.columns)

# %%
X.head()
# Out:
#        Runs   At_Bats      Hits   Doubles   Triples  Home_Runs     Walks  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845  -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917  -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.088700  1.733325 -0.276617  -0.697101  1.252941
# 3 -1.329231  0.233951 -0.347747 -0.800621 -0.474688  -0.869006 -1.145857
# 4  0.174084  1.255894  2.030708  0.908319  1.704094  -0.353293 -0.197495
#
#    Strikeouts  Stolen_Bases  Runs_Allowed  Earned_Runs       ERA  Shutouts  \
# 0   -2.727623      0.905953     -0.664514    -0.511148 -0.511388 -0.787002
# 1    0.121896     -0.585315      0.154638     0.232161  0.238952  0.236737
# 2   -0.925866      0.116458     -0.678397    -0.754153 -0.643801 -0.252844
# 3   -0.201246     -0.673037      0.168522     0.089217  0.040333 -0.513555
# 4    0.072935     -0.015124      1.584683     1.561540  1.496876  0.236737
#
#       Saves    Errors
# 0  1.532753 -0.348265
# 1  0.312020 -0.540820
# ...

# %% [markdown]
# # Multicolinearity:

# %% [markdown]
# We can see that there is a multicolinearty issue in the dataset.So we need to get rid of it using VIF(Variance inflation factor) .

# %%
#Checking for multicolinearity using VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features      Features
# 0       7.059558          Runs
# 1      15.816863       At_Bats
# 2       8.961241          Hits
# 3       2.740739       Doubles
# 4       3.223456       Triples
# 5       8.624865     Home_Runs
# 6       2.688030         Walks
# 7       2.741811    Strikeouts
# 8       1.885106  Stolen_Bases
# 9     190.835154  Runs_Allowed
# 10   1811.284650   Earned_Runs
# 11   1446.557435           ERA
# 12      3.250610      Shutouts
# 13      4.282243         Saves
# 14      2.140709        Errors

# %% [markdown]
# By looking into the VIF values we can say that multicolinearity exists in At_Bats, Hits, Runs_Allowed, Earned_Runs and ERA.So let me drop Runs_Allowed and Earned_Runs columns to avoid multicolinearity.

# %%
#Droping Earned_Runs
X = X.drop(["Earned_Runs"],axis=1)

# %%
#Checking the values in the dependent variable columns
X.head()
# Out:
#        Runs   At_Bats      Hits   Doubles   Triples  Home_Runs     Walks  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845  -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917  -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.088700  1.733325 -0.276617  -0.697101  1.252941
# 3 -1.329231  0.233951 -0.347747 -0.800621 -0.474688  -0.869006 -1.145857
# 4  0.174084  1.255894  2.030708  0.908319  1.704094  -0.353293 -0.197495
#
#    Strikeouts  Stolen_Bases  Runs_Allowed       ERA  Shutouts     Saves  \
# 0   -2.727623      0.905953     -0.664514 -0.511388 -0.787002  1.532753
# 1    0.121896     -0.585315      0.154638  0.238952  0.236737  0.312020
# 2   -0.925866      0.116458     -0.678397 -0.643801 -0.252844 -0.664137
# 3   -0.201246     -0.673037      0.168522  0.040333 -0.513555 -0.820689
# 4    0.072935     -0.015124      1.584683  1.496876  0.236737 -1.149165
#
#      Errors
# 0 -0.348265
# 1 -0.540820
# 2 -1.326125
# 3  0.650818
# 4 -0.540820

# %%
#Checking for multicolinearity using VIF after dropping Earned_Runs
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features      Features
# 0       5.660606          Runs
# 1       6.989802       At_Bats
# 2       8.681013          Hits
# 3       2.680390       Doubles
# 4       3.122426       Triples
# 5       6.848258     Home_Runs
# 6       2.572233         Walks
# 7       2.667701    Strikeouts
# 8       1.771569  Stolen_Bases
# 9     142.333856  Runs_Allowed
# 10    140.684786           ERA
# 11      3.040895      Shutouts
# 12      2.179121         Saves
# 13      2.128660        Errors

# %% [markdown]
# VIF is high for 2 columns Runs_Allowed and ERA so let us drop Runs_Allowed.

# %%
#Droping Runs_Allowed
X = X.drop(["Runs_Allowed"],axis=1)

# %%
#Checking for multicolinearity using VIF after dropping Runs_Allowed
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features      Features
# 0       5.635251          Runs
# 1       4.221639       At_Bats
# 2       7.315185          Hits
# 3       2.669093       Doubles
# 4       3.045099       Triples
# 5       5.598676     Home_Runs
# 6       2.327682         Walks
# 7       2.101266    Strikeouts
# 8       1.736254  Stolen_Bases
# 9       4.528987           ERA
# 10      2.914221      Shutouts
# 11      2.110169         Saves
# 12      2.083960        Errors

# %% [markdown]
# We can still see some values higher than 4 so lets drop one more column with highest VIF - Hits

# %%
#Droping Runs_Allowed
X = X.drop(["Hits"],axis=1)

# %%
#Checking for multicolinearity using VIF after dropping Hits
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features      Features
# 0       4.250076          Runs
# 1       2.238746       At_Bats
# 2       2.597917       Doubles
# 3       3.030073       Triples
# 4       4.562014     Home_Runs
# 5       2.222720         Walks
# 6       2.042786    Strikeouts
# 7       1.568151  Stolen_Bases
# 8       3.878177           ERA
# 9       2.651314      Shutouts
# 10      1.954370         Saves
# 11      1.493128        Errors

# %% [markdown]
# The VIF values can be seen improved now. Lets proceed to next step.

# %% [markdown]
# # Finding Best Random State and Accuracy:

# %%
#Finding the best Accuracy and Random state.
from sklearn.linear_model import LinearRegression
maxAccu=0
maxRS=0
for i in range(1,200):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.30, random_state =i)
    mod = LinearRegression()
    mod.fit(X_train, y_train)
    pred = mod.predict(X_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.9291790579976077  on Random_state  50

# %% [markdown]
# We have got the best Accuracy and Random state.

# %% [markdown]
# # Regression Algorithms:

# %%
#importing necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingRegressor
from sklearn import metrics

# %% [markdown]
# ## 1. Linear Regression:

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
pred=lr.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print('root_mean_squared_error:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8825441695523603
# mean_squared_error: 11.876089523039132
# mean_absolute_error: 2.858063491059203
# root_mean_squared_error: 3.4461702690144507

# %% [markdown]
# ## 2.Lasso regressor:

# %%
#importing necessary library
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
ls=Lasso()
Z=GridSearchCV(ls,parameters)
Z.fit(X_train,y_train)
print(Z.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(X_train,y_train)
pred=ls.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.9074008412166027
# mse: 9.362803832543511
# mae: 2.503466677712074
# rmse: 3.0598699045128552

# %% [markdown]
# ## 3. Ridge Regressor:

# %%
parameters={'alpha':[0.001,0.01,0.1,1,10],'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga']}
rd=Ridge()
Z1=GridSearchCV(rd,parameters)
Z1.fit(X_train,y_train)
print(Z1.best_params_)
# Out:
# {'alpha': 10, 'solver': 'lsqr'}

# %%
rd=Ridge(alpha=10,solver='lsqr')
rd.fit(X_train,y_train)
pred=rd.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.7640697457240868
# mse: 23.85517015456456
# mae: 3.6356131527940914
# rmse: 4.884175483596445

# %% [markdown]
# ## 4. SGD:

# %%
sgd=SGDRegressor()
sgd.fit(X_train,y_train)
pred=sgd.predict(X_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.9004222904369252
# mse: 10.068412855822011
# mae: 2.5456244106372137
# rmse: 3.1730762448800394

# %% [markdown]
# # Cross_Validation_Score:

# %%
print(cross_val_score(lr,X,y,cv=5).mean())
# Out:
# 0.37344412304899344

# %%
print(cross_val_score(ls,X,y,cv=5).mean())
# Out:
# 0.5206537019436117

# %%
print(cross_val_score(rd,X,y,cv=5).mean())
# Out:
# 0.3521603094798834

# %%
print(cross_val_score(sgd,X,y,cv=5).mean())
# Out:
# 0.2632139369033973

# %% [markdown]
# Above are the cross validation scores of lr, ls and rd, sgd.
#
# And we can find that the difference between model accuracy and cross validation score is less for lasso. So lasso is the best model to proceed.

# %% [markdown]
# # HyperParameter tuning:

# %%
#importing necessary libraries
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'alpha':[0.01, 0.1, 1.0,10.26],
              'selection':['cyclic','random'],
              'max_iter':[2,4,6,8,10],
              'tol':[100,1000],
              'fit_intercept':['bool']}

# %%
# Giving lasso parameters.
GCV=GridSearchCV(Lasso(),parameter,cv=5)

# %%
#Tuning the model with GCV.
GCV.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
#These are the best parameters.
GCV.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': 'bool',
#  'max_iter': 10,
#  'selection': 'random',
#  'tol': 1000}

# %%
Final_model=Lasso(alpha=1.0, fit_intercept="bool", max_iter=10, selection="random", tol=1000)
Final_model.fit(X_train,y_train)
pred=Final_model.predict(X_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# R2_Score: 88.73577689257742
# mean_squared_error: 11.389381141949492
# mean_absolute_error: 3.022112377695933
# RMSE value: 3.3748157197022612

# %% [markdown]
# After tuning we have got an accuracy of 88.73% , which is good.

# %% [markdown]
# # Saving the model:

# %%
# Saving the model using .pkl
import joblib
joblib.dump(Final_model,"BaseBallCaseStudy.pkl")
# Out:
# ['BaseBallCaseStudy.pkl']

# %% [markdown]
# # Predictions:

# %%
# Loading the saved model
model=joblib.load("BaseBallCaseStudy.pkl")

#Prediction
prediction = model.predict(X_test)
prediction
# Out:
# array([91.95139236, 78.36080468, 82.02862099, 81.2669748 , 95.86151398,
#        86.29769158, 76.75531073, 83.44588001, 71.98596773])

# %% [markdown]
# These are the predictions we got using the model saved.

# %%
pd.DataFrame([model.predict(X_test)[:],y_test[:]],index=["Predictions","Original"])
# Out:
#                      0          1          2          3           4  \
# Predictions  91.951392  78.360805  82.028621  81.266975   95.861514
# Original     98.000000  76.000000  79.000000  84.000000  100.000000
#
#                      5          6         7          8
# Predictions  86.297692  76.755311  83.44588  71.985968
# Original     88.000000  74.000000  83.00000  68.000000

# %%
#Plotting predicted vs. actual values

plt.figure(figsize=[15,6])
sns.lineplot(x=prediction, y=y_test)
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Predicted vs. Actual Values')
plt.show()

# %% [markdown]
# It can be observed that the predictions are almost close to original values apart from the fact that there are a few exceptions.
